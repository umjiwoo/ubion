# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 선 그래프
x=[1,2,3,4]
y=[5,3,2,1]

plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
plt.barh(x,y)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
color = np.random.rand(50)
area = (20*np.random.rand(50))**2  #random.rand(50)->0~1사이의 값을 50개 반환

# %%
plt.scatter(x,y)
plt.show()

# %%
# s=scale,c=color,alpha=transparency(투명도)
plt.scatter(x,y,s=area,c=color,alpha=0.6)
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.34.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\umjiwoo\appdata\roaming\python\python39\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# drinks.csv 파일 로드
drinks = pd.read_csv("./csv/drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
corr = drinks[
    ['beer_servings','spirit_servings','wine_servings','total_litres_of_pure_alcohol']
].corr(method='pearson')
corr
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# 히트맵 출력
cols_views = ['beer','spirit','wine','alcohol']
sns.set(font_scale=1.5)
hm = sns.heatmap(corr.values,
                cbar=True, # color_bar ; 상관계수 값에 따른 색상값 바 형태로 보여줌
                annot=True, # 각각의 상관계수 값을 칸마다 출력
                square=True, # 히트맵을 정사각형으로 출력
                fmt='.2f', # 상관계수 값을 소수점 몇자리까지 출력할 것인지 지정
                annot_kws={'size':20}, # 상관계수 값 폰트 크기
                xticklabels=cols_views,
                yticklabels=cols_views)

plt.tight_layout()
plt.show()

# %%
sns.set(style='darkgrid', context='notebook')


sns.pairplot(
    drinks[
        [
        'beer_servings',
        'spirit_servings',
        'wine_servings',
        'total_litres_of_pure_alcohol'
        ]
    ],height=2.5
)

plt.show()
