# %% [markdown]
# ### 워드클라우드
#
#  - 라이브러리 이름 : wordcloud

# %%
# !pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (1.8.2.2)
# Requirement already satisfied: pillow in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from WordCloud) (9.1.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from WordCloud) (1.23.1)
# Requirement already satisfied: matplotlib in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from WordCloud) (3.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->WordCloud) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->WordCloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->WordCloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->WordCloud) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install konlpy

# %%
from wordcloud import WordCloud
from konlpy.tag import Okt
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
text = open("hiphop.txt",encoding="euc-kr").read()

# %%
okt = Okt()

# Okt 함수 이용해 내용 형태 분석
nouns = okt.nouns(text)

# %%
# 두 글자 이상인 nouns의 항목들만 추출
words = [n for n in nouns if len(n)>1]

# %%
# Counter() ; 단어 당 몇번씩 쓰였는지 세줌
cnt = Counter(words)

# %%
img = Image.open("pngwing.png")
img_array = np.array(img)

wc = WordCloud(
    font_path="malgun",
    width=400,
    height=400,
    scale=2.0,
    max_font_size=250,
    max_words=50,
    mask = img_array
)

gen = wc.generate_from_frequencies(cnt)
plt.figure()
plt.axis("off")
plt.imshow(gen)
# Out:
# Found existing installation: collection 0.1.6
# Uninstalling collection-0.1.6:
#   Would remove:
#     c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages\collection-0.1.6.dist-info\*
#     c:\users\umjiwoo\appdata\local\programs\python\python39\lib\site-packages\collection\*
# Proceed (Y/n)?
